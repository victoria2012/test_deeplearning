# %% [markdown]
# <a href="https://colab.research.google.com/github/victoria2012/test_deeplearning/blob/master/readfrom_google_drive.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
# !ls ./drive/MyDrive/Test
# Out:
#  autompg_xgboost.ipynb			 multi_perceptron.ipynb
#  autompg_xgboost_service.ipynb		 python_function.ipynb
#  boston_housingwithregression.ipynb	 reuter_LSTM.ipynb
#  boston_linearregression.ipynb		 reuters_embedding.ipynb
#  boston_linearregression_service.ipynb	 roc_curve.ipynb
#  CEO3.csv				 single_perceptron.ipynb
#  colab_first.ipynb			 Untitled
#  datapreprocess_fillna.ipynb		 Untitled0.ipynb
#  diff_sigmoid_softmax.ipynb		 Untitled1.ipynb
# ' embedding_layer.ipynb'		 Untitled2.ipynb
# '코딩공부 참고자료.gsheet'		 Untitled3.ipynb
#  iloc_pandas.ipynb			 Untitled4.ipynb
#  imdb_embedding.ipynb			 Untitled5.ipynb
#  imdb_LSTM.ipynb			 Untitled6.ipynb
#  iris_classification.ipynb		 Untitled7.ipynb
#  learn_KFold.ipynb			 wine_classification.ipynb
#  mnist_classification.ipynb

# %%
pd.read_csv('./drive/MyDrive/Test/CEO3.csv', encoding='latin')
# pd.read_csv('./CEO3.csv', encoding='latin')
# Out:
#      number               firm  ...  Unnamed: 458 Unnamed: 459
# 0         2       Amorepacific  ...           NaN          NaN
# 1         4       Amorepacific  ...           NaN          NaN
# 2       502       Amorepacific  ...           NaN          NaN
# 3         5    Asiana Airlines  ...           NaN          NaN
# 4         6    Asiana Airlines  ...           NaN          NaN
# ..      ...                ...  ...           ...          ...
# 373     486  Wyndham Worldwide  ...           NaN          NaN
# 374     487  Wyndham Worldwide  ...           NaN          NaN
# 375     488  Wyndham Worldwide  ...           NaN          NaN
# 376     490             Xilinx  ...           NaN          NaN
# 377     623             Xilinx  ...           NaN          NaN
#
# [378 rows x 460 columns]
